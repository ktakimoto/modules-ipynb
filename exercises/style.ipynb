# %%
from IPython.display import HTML

hide_me = ''
HTML('''<script>
code_show=true; 
function code_toggle() {
  if (code_show) {
    $('div.input').each(function(id) {
      el = $(this).find('.cm-variable:first');
      if (id == 0 || el.text() == 'hide_me') {
        $(this).hide();
      }
    });
    $('div.output_prompt').css('opacity', 0);
  } else {
    $('div.input').each(function(id) {
      $(this).show();
    });
    $('div.output_prompt').css('opacity', 1);
  }
  code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input style="opacity:1" type="submit" value="Click here to reveal the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#   if (code_show) {
#     $('div.input').each(function(id) {
#       el = $(this).find('.cm-variable:first');
#       if (id == 0 || el.text() == 'hide_me') {
#         $(this).hide();
#       }
#     });
#     $('div.output_prompt').css('opacity', 0);
#   } else {
#     $('div.input').each(function(id) {
#       $(this).show();
#     });
#     $('div.output_prompt').css('opacity', 1);
#   }
#   code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input style="opacity:1" type="submit" value="Click here to reveal the raw code."></form>

# %% [markdown]
# # Berkeley Data Science Modules: Styling
# <img src="https://jupyter.org/assets/main-logo.svg" style="width: 500px; height: 350px;"/>
#
# *In this notebook, we'll go through some example code for common styling flair used in UC Berkeley's Data Science Modules Program Jupyter notebooks.*
#
# ### Table of Contents
# 1. Hiding Cells
# 2. Alert Boxes
# 3. Images
# 4. Videos
# 5. Converting notebooks to pdf with GSExport

# %%
# dependencies: THIS CELL MUST BE RUN
from datascience import *
import numpy as np
import math
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import ipywidgets as widgets
# %matplotlib inline

# %% [markdown]
# ## Hiding Cells

# %% [markdown]
# Sometimes when the intent of the module is not to teach coding, it may make sense stylistically to hide some or all code cells.

# %% [markdown]
# ### Hide selected code cells (with option to toggle on and off)
# The very top of this notebook has a button to reveal hidden code cells. Click the button to also reveal the code needed to hide select code cells. Note that cell outputs and widgets should still be visable.
#
# To indicate that a code cell should be hidden, add `hide_me` as the first line of any code cells you want hidden. As an example, there is a hidden code cell immediately under this cell. Click the button at the top to reveal it.

# %%
hide_me
def f(x):
    return x

# %% [markdown]
# ### Hide all code cells (with option to toggle on and off)
# For some modules, you may want to hide all code inputs. The following cell has the code to hide every code cell in the notebook (outputs and widgets will still be displayed). Run the cell to hide code cells, and click the blue underlined "here" to bring the code cells back.

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# ## Alert Boxes
#
# Modules often use **alert boxes** to draw attention to exercises or hints.
#
# Note: Markdown formatting generally doesn't work inside alert boxes. Use html instead.

# %% [markdown]
# <div class="alert alert-success">
# <b> A Success box </b>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b> Explain the difference between correlation and causation </b>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> An Info box </b>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b> A Warning box </b>
# </div>

# %% [markdown]
# ## Images
#
# Embed using a local path:

# %% [markdown]
# <img src="../images/Data_scientist_Venn_diagram.png" alt="Data scientist Venn diagram"/>

# %% [markdown]
# Or embed using a url:

# %% [markdown]
# <img src="https://news.berkeley.edu/wp-content/uploads/2016/09/Oskicupcake500-1.jpg"/>

# %% [markdown]
# Change the style attribute to adjust the size:

# %% [markdown]
# <img src="../images/Data_scientist_Venn_diagram.png" alt="Data scientist Venn diagram" style="width:300px;height:300px;">

# %% [markdown]
# ## Videos

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('7nSCZuvtO4M', #the ID of the video
             width=500, #size attributes
             height=400)

# %% [markdown]
# ## Converting to pdf (GSExport)
# For most modules where the students need to turn in notebook work as an assignment, not all parts of the notebook are required for grading. Furthermore, the built-in PDF converter can sometimes give weirdly-formatted outputs, especially with regards to graphical outputs. [GSExport](https://github.com/dibyaghosh/gsExport) is a utility designed by a Berkeley student to address some of these issues.
#
# GSExport is not available by default on Berkeley's DataHub (as of 10/2/19), so we need to install it first.

# %%
# !pip install gsExport
# Out:
# Requirement already satisfied: gsExport in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: jupyter in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: notebook in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: okpy in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: pytz in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: tqdm in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: nbconvert<5 in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: nbformat in /srv/app/venv/lib/python3.6/site-packages (from gsExport)
# Requirement already satisfied: qtconsole in /srv/app/venv/lib/python3.6/site-packages (from jupyter->gsExport)
# Requirement already satisfied: ipywidgets in /srv/app/venv/lib/python3.6/site-packages (from jupyter->gsExport)
# Requirement already satisfied: jupyter-console in /srv/app/venv/lib/python3.6/site-packages (from jupyter->gsExport)
# Requirement already satisfied: ipykernel in /srv/app/venv/lib/python3.6/site-packages (from jupyter->gsExport)
# Requirement already satisfied: prometheus-client in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: Send2Trash in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: jupyter-client>=5.2.0 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: jupyter-core>=4.4.0 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: pyzmq>=17 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: ipython-genutils in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: traitlets>=4.2.1 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: terminado>=0.8.1 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: tornado<7,>=4.1 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: jinja2 in /srv/app/venv/lib/python3.6/site-packages (from notebook->gsExport)
# Requirement already satisfied: requests==2.12.4 in /srv/app/venv/lib/python3.6/site-packages (from okpy->gsExport)
# Requirement already satisfied: mistune!=0.6 in /srv/app/venv/lib/python3.6/site-packages (from nbconvert<5->gsExport)
# Requirement already satisfied: entrypoints in /srv/app/venv/lib/python3.6/site-packages (from nbconvert<5->gsExport)
# Requirement already satisfied: pygments in /srv/app/venv/lib/python3.6/site-packages (from nbconvert<5->gsExport)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/app/venv/lib/python3.6/site-packages (from nbformat->gsExport)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /srv/app/venv/lib/python3.6/site-packages (from ipywidgets->jupyter->gsExport)
# Requirement already satisfied: widgetsnbextension~=3.2.0 in /srv/app/venv/lib/python3.6/site-packages (from ipywidgets->jupyter->gsExport)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /srv/app/venv/lib/python3.6/site-packages (from jupyter-console->jupyter->gsExport)
# Requirement already satisfied: python-dateutil>=2.1 in /srv/app/venv/lib/python3.6/site-packages (from jupyter-client>=5.2.0->notebook->gsExport)
# Requirement already satisfied: decorator in /srv/app/venv/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook->gsExport)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook->gsExport)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /srv/app/venv/lib/python3.6/site-packages (from terminado>=0.8.1->notebook->gsExport)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/app/venv/lib/python3.6/site-packages (from jinja2->notebook->gsExport)
# Requirement already satisfied: pyrsistent>=0.14.0 in /srv/app/venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->gsExport)
# Requirement already satisfied: setuptools in /srv/app/venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->gsExport)
# Requirement already satisfied: attrs>=17.4.0 in /srv/app/venv/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->gsExport)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /srv/app/venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->gsExport)
# Requirement already satisfied: pickleshare in /srv/app/venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->gsExport)
# Requirement already satisfied: backcall in /srv/app/venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->gsExport)
# Requirement already satisfied: jedi>=0.10 in /srv/app/venv/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->gsExport)
# Requirement already satisfied: wcwidth in /srv/app/venv/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->jupyter-console->jupyter->gsExport)
# Requirement already satisfied: parso>=0.5.0 in /srv/app/venv/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter->gsExport)

# %%
import gsExport

# %% [markdown]
# GSExport works by altering the metadata of the notebook. The notebook creator first indicates which cells should be included in the PDF (both Markdown and code cells) by adding "#student" to those cells.

# %%
# TODO: add the correct tag to this cell to include it in the pdf
x = ...

# %% [markdown]
# #student
# **TODO: add the correct tag to this cell to include it in the pdf.**

# %% [markdown]
# If desired, you can also add "#newpage" to Markdown cells to indicate there should be a pagebreak in the PDF at that point.

# %% [markdown]
# **TODO: put a page break at the top of this cell, then tag the cell for inclusion in the pdf**

# %% [markdown]
# The next step is to run the following command in the shell, where the third item is the name of the notebook. This will generate a new notebook called "[original name].nbconvert.ipynb" where the "#student" tags are hidden in the metadata.
#
# Make sure the notebook has been saved before you generate the new version!

# %%
# TODO: replace the ellipses with the name of the notebook to convert it
# !jupyter nbconvert style.ipynb --NotebookExporter.preprocessors="['gsExport.gsExportPreprocessor']" --to notebook
# Out:
# Traceback (most recent call last):
#   File "/srv/app/venv/bin/jupyter-nbconvert", line 7, in <module>
#     from nbconvert.nbconvertapp import main
#   File "/srv/app/venv/lib/python3.6/site-packages/nbconvert/__init__.py", line 7, in <module>
#     from . import postprocessors
#   File "/srv/app/venv/lib/python3.6/site-packages/nbconvert/postprocessors/__init__.py", line 5, in <module>
#     from .serve import ServePostProcessor
#   File "/srv/app/venv/lib/python3.6/site-packages/nbconvert/postprocessors/serve.py", line 19, in <module>
#     class ProxyHandler(web.RequestHandler):
#   File "/srv/app/venv/lib/python3.6/site-packages/nbconvert/postprocessors/serve.py", line 21, in ProxyHandler
#     @web.asynchronous
# AttributeError: module 'tornado.web' has no attribute 'asynchronous'

# %% [markdown]
# **This new notebook is the one that is distributed to students** (renaming it is fine). From the new notebook, students run the following commands to generate a PDF that includes only the tagged cells and their outputs.

# %%
#generate the pdf
# !pip install gsExport -q
import gsExport
gsExport.generateSubmission("style.nbconvert.ipynb")
# Out:
# Processing style.nbconvert.ipynb
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-3211f76773b5> in <module>
#       2 get_ipython().system('pip install gsExport -q')
#       3 import gsExport
# ----> 4 gsExport.generateSubmission("style.nbconvert.ipynb")
#
# /srv/app/venv/lib/python3.6/site-packages/gsExport/exporter.py in generateSubmission(fileName, **kwargs)
#      19         print("You can't run this command from outside the Jupyter Notebook!")
#      20         return
# ---> 21     diffed = generate_filtered(fileName)
#      22     header = headings.generate_header()
#      23     if header is not None:
#
# /srv/app/venv/lib/python3.6/site-packages/gsExport/exporter.py in generate_filtered(input_file)
#      11 def generate_filtered(input_file):
#      12     print("Processing %s"%input_file)
# ---> 13     student_notebook = load_notebook(input_file)
#      14     filtered = filter_nb(student_notebook)
#      15     return filtered
#
# /srv/app/venv/lib/python3.6/site-packages/gsExport/utils.py in load_notebook(name)
#       6
#       7 def load_notebook(name):
# ----> 8     return nbf.read(name,nbf.current_nbformat)
#       9
#      10 def save_notebook(nb,name):
#
# /srv/app/venv/lib/python3.6/site-packages/nbformat/__init__.py in read(fp, as_version, **kwargs)
#     136     """
#     137     if isinstance(fp, (py3compat.unicode_type, bytes)):
# --> 138         with io.open(fp, encoding='utf-8') as f:
#     139             return read(f, as_version, **kwargs)
#     140
#
# FileNotFoundError: [Errno 2] No such file or directory: 'style.nbconvert.ipynb'

# %% [markdown]
# Once the students click on the "Download this" link that appears in the cell output, the PDF will be written to a file in the same directory as the notebook and (depending on the browser settings) open in a new tab.

# %% [markdown]
# #### References
# * "Data Scientist Venn Diagram" image by Stephan Kolassa, 18 November 2015. [source](http://www.prooffreader.com/2016/09/battle-of-data-science-venn-diagrams.html)
# * Code for hiding selected code cells adapted from code by Amitrajit Bose, 26 December 2018. [source](https://amitrajitbose.github.io/blog/hiding-input-cells-jupyter-notebook/)
# * Code for hiding all code cells by Damien Kao, 17 September 2014. [source](https://blog.nextgenetics.net/?e=102)

# %% [markdown]
# Author: Keeley Takimoto
